# %% [markdown]
# <a href="https://colab.research.google.com/github/Kopfgeldjaeger/Covid-19_in_germany/blob/master/covid_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
cwd = os.getcwd()
print(cwd)
# %ls 
print('\t')
from zipfile import ZipFile
file_name = 'vg2500_geo84.zip'
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done.')
# %ls
# Out:
# /content
# de_100km.dbf  de_10km.dbf  de_1km.dbf  Germany_shapefile.zip
# de_100km.png  de_10km.png  de_1km.png  sample_data/
# de_100km.prj  de_10km.prj  de_1km.prj  vg2500_geo84.zip
# de_100km.shp  de_10km.shp  de_1km.shp
# de_100km.shx  de_10km.shx  de_1km.shx
#
# Done.
# aktualitaet.txt  de_10km.shp            vg2500_bld.dbf    vg2500_rbz.dbf
# de_100km.dbf     de_10km.shx            vg2500_bld.prj    vg2500_rbz.prj
# de_100km.png     de_1km.dbf             vg2500_bld.shp    vg2500_rbz.shp
# de_100km.prj     de_1km.png             vg2500_bld.shx    vg2500_rbz.shx
# de_100km.shp     de_1km.prj             vg2500_geo84.zip  vg2500_sta.dbf
# de_100km.shx     de_1km.shp             vg2500_krs.dbf    vg2500_sta.prj
# de_10km.dbf      de_1km.shx             vg2500_krs.prj    vg2500_sta.shp
# de_10km.png      Germany_shapefile.zip  vg2500_krs.shp    vg2500_sta.shx
# de_10km.prj      sample_data/           vg2500_krs.shx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install geopandas
import geopandas as gpd
# Out:
# ...
#      |████████████████████████████████| 931kB 4.9MB/s
# ...
#      |████████████████████████████████| 14.7MB 210kB/s
# ...
#      |████████████████████████████████| 10.4MB 40.8MB/s
# ...

# %%
fp = "vg2500_bld.shp"

map_df = gpd.read_file(fp)

# check data type so we can see that this is not a normal dataframe, but a GEOdataframe
map_df.head()
# Out:
#    USE  RS  ...    SHAPE_AREA                                           geometry
# 0    2  02  ...  7.605398e+08  MULTIPOLYGON (((10.19114 53.72299, 10.18210 53...
# 1    2  03  ...  4.771641e+10  MULTIPOLYGON (((8.68962 53.87999, 8.69297 53.8...
# 2    2  04  ...  4.054809e+08  MULTIPOLYGON (((8.52976 53.21640, 8.55399 53.2...
# 3    2  05  ...  3.404727e+10  POLYGON ((8.66673 52.52149, 8.70289 52.50053, ...
# 4    2  06  ...  2.109232e+10  POLYGON ((9.50560 51.62777, 9.50842 51.62712, ...
#
# [5 rows x 7 columns]

# %%
map_df.plot()

# %%
map_df
# Out:
#     USE  RS  ...    SHAPE_AREA                                           geometry
# 0     2  02  ...  7.605398e+08  MULTIPOLYGON (((10.19114 53.72299, 10.18210 53...
# 1     2  03  ...  4.771641e+10  MULTIPOLYGON (((8.68962 53.87999, 8.69297 53.8...
# 2     2  04  ...  4.054809e+08  MULTIPOLYGON (((8.52976 53.21640, 8.55399 53.2...
# 3     2  05  ...  3.404727e+10  POLYGON ((8.66673 52.52149, 8.70289 52.50053, ...
# 4     2  06  ...  2.109232e+10  POLYGON ((9.50560 51.62777, 9.50842 51.62712, ...
# 5     2  07  ...  1.983491e+10  POLYGON ((7.84657 50.87861, 7.85901 50.87733, ...
# 6     2  08  ...  3.580140e+10  MULTIPOLYGON (((9.64634 49.77782, 9.63806 49.7...
# 7     2  09  ...  7.055007e+10  POLYGON ((10.47207 47.56964, 10.47319 47.57081...
# 8     2  10  ...  2.578542e+09  POLYGON ((7.06853 49.62349, 7.08023 49.61196, ...
# 9     2  11  ...  8.864801e+08  POLYGON ((13.61192 52.54332, 13.62461 52.53797...
# ...

# %%
con= pd.read_excel("covid19_de.xlsx",header=0)
con= con.fillna(0)
con
# Out:
#                        GEN  27_01_2020  ...  26_02_2020  27_02_2020
# 0                  Hamburg         0.0  ...         0.0         0.0
# 1            Niedersachsen         0.0  ...         0.0         0.0
# 2                   Bremen         0.0  ...         0.0         0.0
# 3      Nordrhein-Westfalen         0.0  ...         5.0         5.0
# 4                   Hessen         0.0  ...         2.0         2.0
# 5          Rheinland-Pfalz         0.0  ...         0.0         1.0
# 6        Baden-Württemberg         0.0  ...         4.0         4.0
# 7                   Bayern         1.0  ...        14.0        14.0
# 8                 Saarland         0.0  ...         0.0         0.0
# 9                   Berlin         0.0  ...         0.0         0.0
# 10             Brandenburg         0.0  ...         0.0         0.0
# 11  Mecklenburg-Vorpommern         0.0  ...         0.0         0.0
# 12                 Sachsen         0.0  ...         0.0         0.0
# ...

# %%
print(con.index[2])
#con = con[['GEN','27_01_2020']]
#con =con.loc[:, ['GEN','27_01_2020','28_01_2020']]
con = con[['GEN','27_01_2020','28_01_2020','31_01_2020','02_02_2020','04_02_2020','10_02_2020','14_02_2020','25_02_2020','26_02_2020','27_02_2020']]
con
#con = con[['GEN','2020_01_27','2020_01_28','2020_01_30','2020_01_31','2020_02_01','2020_02_02','2020_02_04','2020_02_06','2020_02_07','2020_02_12','2020_02_25','2020_02_26','2020_02_27']]
# Out:
# 2
#                        GEN  27_01_2020  ...  26_02_2020  27_02_2020
# 0                  Hamburg         0.0  ...         0.0         0.0
# 1            Niedersachsen         0.0  ...         0.0         0.0
# 2                   Bremen         0.0  ...         0.0         0.0
# 3      Nordrhein-Westfalen         0.0  ...         5.0         5.0
# 4                   Hessen         0.0  ...         2.0         2.0
# 5          Rheinland-Pfalz         0.0  ...         0.0         1.0
# 6        Baden-Württemberg         0.0  ...         4.0         4.0
# 7                   Bayern         1.0  ...        14.0        14.0
# 8                 Saarland         0.0  ...         0.0         0.0
# 9                   Berlin         0.0  ...         0.0         0.0
# 10             Brandenburg         0.0  ...         0.0         0.0
# 11  Mecklenburg-Vorpommern         0.0  ...         0.0         0.0
# 12                 Sachsen         0.0  ...         0.0         0.0
# ...

# %%
merged = map_df.set_index('GEN').join(con.set_index('GEN'))
merged
# Out:
#                         USE  RS  ... 26_02_2020  27_02_2020
# GEN                              ...
# Hamburg                   2  02  ...        0.0         0.0
# Niedersachsen             2  03  ...        0.0         0.0
# Bremen                    2  04  ...        0.0         0.0
# Nordrhein-Westfalen       2  05  ...        5.0         5.0
# Hessen                    2  06  ...        2.0         2.0
# Rheinland-Pfalz           2  07  ...        0.0         1.0
# Baden-Württemberg         2  08  ...        4.0         4.0
# Bayern                    2  09  ...       14.0        14.0
# Saarland                  2  10  ...        0.0         0.0
# Berlin                    2  11  ...        0.0         0.0
# Brandenburg               2  12  ...        0.0         0.0
# Mecklenburg-Vorpommern    2  13  ...        0.0         0.0
# Sachsen                   2  14  ...        0.0         0.0
# Sachsen-Anhalt            2  15  ...        0.0         0.0
# ...

# %%
Vlist = ['27_01_2020','28_01_2020','31_01_2020','02_02_2020','04_02_2020','10_02_2020','14_02_2020','25_02_2020','26_02_2020','27_02_2020']
n=0
# set a variable that will call whatever column we want to visualise on the map
for i in Vlist:
  variable = i
  n=n+1
  # set the range for the choropleth
  vmin, vmax = 0, 30

  # create figure and axes for Matplotlib
  fig, ax = plt.subplots(1, figsize=(10, 6))
  merged.plot(column=variable, cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8')
  # remove the axis
  ax.axis('off')

  # add a title
  ax.set_title('Covid-19 in Germany', \
                fontdict={'fontsize': '25',
                          'fontweight' : '3'})
  ax.annotate('Source: Xia, KIT, 2020',
            xy=(0.1, .08), xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top',
            fontsize=10, color='#555555')
  sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
  sm._A = []
  cbar = fig.colorbar(sm)
  fig.savefig(str(n)+'testmap.png', dpi=300)

# %%
import matplotlib.animation as animation
# this methode with plt a gif to generate hasn't been finished.

# %%
# !apt install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono ghostscript gsfonts
#   imagemagick-6-common imagemagick-6.q16 libcupsfilters1 libcupsimage2
#   libdjvulibre-text libdjvulibre21 libgs9 libgs9-common libijs-0.35
#   libjbig2dec0 liblqr-1-0 libmagickcore-6.q16-3 libmagickcore-6.q16-3-extra
#   libmagickwand-6.q16-3 libnetpbm10 libwmf0.2-7 netpbm poppler-data
# Suggested packages:
#   fonts-noto ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng
#   enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance
#   sane-utils texlive-base-bin transfig ufraw-batch inkscape libjxr-tools
#   libwmf0.2-7-gtk poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
# ...

# %%
# !convert -version
# Out:
# Version: ImageMagick 6.9.7-4 Q16 x86_64 20170114 http://www.imagemagick.org
# Copyright: © 1999-2017 ImageMagick Studio LLC
# License: http://www.imagemagick.org/script/license.php
# Features: Cipher DPC Modules OpenMP
# Delegates (built-in): bzlib djvu fftw fontconfig freetype jbig jng jpeg lcms lqr ltdl lzma openexr pangocairo png tiff wmf x xml zlib

# %%
# !convert -delay 20 -loop 0 1testmap.png 2testmap.png 3testmap.png 4testmap.png 5testmap.png 6testmap.png 7testmap.png 8testmap.png 9testmap.png 10testmap.png covid19_de.gif
